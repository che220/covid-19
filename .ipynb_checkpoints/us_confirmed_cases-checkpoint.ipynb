# %%
# %config IPCompleter.greedy=True
# %matplotlib inline

# %%
import pandas as pd, numpy as np, os, sys
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from IPython.display import display, HTML

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

font = {'size'   : 18}
matplotlib.rc('font', **font)

def plotHorizontalBars(series, xlabel, title):
    xpos = np.arange(len(series.index), 0, -1)
    plt.barh(xpos, series, align='center', alpha=0.5, color='g')
    plt.grid(axis='x')
    plt.yticks(xpos, series.index)
    plt.xlabel(xlabel)
    plt.title(title)

def plotVerticalBars(series, ylabel, title):
    xpos = np.arange(len(series.index), 0, -1)
    plt.bar(xpos, series, align='center', alpha=0.5, color='g')
    plt.grid(axis='y')
    plt.xticks(xpos, series.index)
    plt.ylabel(ylabel)
    plt.title(title)

# %%
start_date = dt.datetime(2020, 3, 7)
daily_series = [351, 517, 671, 931, 1240, 1690, 2226, 2943, 3738, 4669, 6427, 9351, 13611, 19700, 26800,
               35120, 46100, 55100, 69150, 86000, 104800, 124600, 142600, 164600, 189800, 216200, 245600, 278100,
              312300, 338100]
dates=[]
for i in range(len(daily_series)):
    dates.append(start_date + dt.timedelta(days=i))
daily_cases = list(zip(dates, daily_series))
daily_cases_df = pd.DataFrame(daily_cases, columns=['date', 'cases'])
daily_cases_df['log_cases'] = np.log(daily_cases_df.cases)
daily_cases_df['date_index'] = daily_cases_df.index
daily_cases_df.date_index += 1

daily_cases_df['prev_cases'] = [0] + daily_series[:-1]
daily_cases_df = daily_cases_df.iloc[1:, :].copy()
daily_cases_df['increase'] = daily_cases_df.cases - daily_cases_df.prev_cases
daily_cases_df['pct_increase'] = daily_cases_df.increase / daily_cases_df.prev_cases
display(daily_cases_df)
# Out:
#          date   cases  log_cases  date_index  prev_cases  increase  \
# 1  2020-03-08     517   6.248043           2         351       166
# 2  2020-03-09     671   6.508769           3         517       154
# 3  2020-03-10     931   6.836259           4         671       260
# 4  2020-03-11    1240   7.122867           5         931       309
# 5  2020-03-12    1690   7.432484           6        1240       450
# 6  2020-03-13    2226   7.707962           7        1690       536
# 7  2020-03-14    2943   7.987185           8        2226       717
# 8  2020-03-15    3738   8.226306           9        2943       795
# 9  2020-03-16    4669   8.448700          10        3738       931
# 10 2020-03-17    6427   8.768263          11        4669      1758
# 11 2020-03-18    9351   9.143239          12        6427      2924
# 12 2020-03-19   13611   9.518634          13        9351      4260
# 13 2020-03-20   19700   9.888374          14       13611      6089
# 14 2020-03-21   26800  10.196157          15       19700      7100
# 15 2020-03-22   35120  10.466526          16       26800      8320
# 16 2020-03-23   46100  10.738568          17       35120     10980
# 17 2020-03-24   55100  10.916905          18       46100      9000
# 18 2020-03-25   69150  11.144033          19       55100     14050
# 19 2020-03-26   86000  11.362103          20       69150     16850
# 20 2020-03-27  104800  11.559809          21       86000     18800
# 21 2020-03-28  124600  11.732864          22      104800     19800
# 22 2020-03-29  142600  11.867799          23      124600     18000
# 23 2020-03-30  164600  12.011274          24      142600     22000
# 24 2020-03-31  189800  12.153726          25      164600     25200
# 25 2020-04-01  216200  12.283959          26      189800     26400
# 26 2020-04-02  245600  12.411459          27      216200     29400
# 27 2020-04-03  278100  12.535736          28      245600     32500
# 28 2020-04-04  312300  12.651720          29      278100     34200
# 29 2020-04-05  338100  12.731097          30      312300     25800
#
#     pct_increase
# 1       0.472934
# 2       0.297872
# 3       0.387481
# 4       0.331901
# 5       0.362903
# 6       0.317160
# 7       0.322102
# 8       0.270133
# 9       0.249064
# 10      0.376526
# 11      0.454956
# 12      0.455566
# 13      0.447359
# 14      0.360406
# 15      0.310448
# 16      0.312642
# 17      0.195228
# 18      0.254991
# 19      0.243673
# 20      0.218605
# 21      0.188931
# 22      0.144462
# 23      0.154278
# 24      0.153098
# 25      0.139094
# 26      0.135985
# 27      0.132329
# 28      0.122977
# 29      0.082613

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

pct_df = daily_cases_df[daily_cases_df.date_index >= 18].copy()
reg = LinearRegression()
x = pct_df.date_index.values.reshape(-1, 1)
y = pct_df.pct_increase.values.reshape(-1, 1)
reg.fit(x, y)
y_fit = reg.predict(x)

plt.figure(figsize=(15, 4))
plt.plot(pct_df.date_index, pct_df.pct_increase)
plt.plot(x, y_fit, color='red')
plt.show()

print(reg.coef_)
print(reg.intercept_)
# Out:
# [[-0.01164852]]
# [0.44620028]

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures

x = daily_cases_df.date_index.values.reshape(-1, 1)
poly = PolynomialFeatures(degree=3)
xp = poly.fit_transform(x)

y = daily_cases_df.log_cases.values.reshape(-1, 1)
reg = LinearRegression()
reg.fit(xp, y)
y_fit = reg.predict(xp)

print('Coefficients:', reg.coef_)
print('Intercept:', reg.intercept_)

plt.figure(figsize=(15, 4))
plt.plot(x, y)
plt.plot(x, y_fit, color='red')
plt.show()
# Out:
# Coefficients: [[ 0.00000000e+00  2.72760387e-01  4.45641053e-03 -1.92345395e-04]]
# Intercept: [5.63608487]

# %%
x_fut = x.copy()
x_fut -= x.min()
x_fut += x.max()
xp_fut = poly.fit_transform(x_fut)
y_fut = reg.predict(xp_fut)

print(y_fut)
y_fut = np.exp(y_fut).astype(int)

x_fut = np.apply_along_axis(lambda x: (start_date+dt.timedelta(days=int(x))).strftime('%Y-%m-%d'),
                            arr=x_fut, axis=1)
mat = np.c_[x_fut, y_fut]
print(mat)
# Out:
# [[12.63634031]
#  [12.64410574]
#  [12.62500775]
#  [12.57789226]
#  [12.50160521]
#  [12.39499252]
#  [12.25690012]
#  [12.08617393]
#  [11.88165989]
#  [11.64220392]
#  [11.36665194]
#  [11.0538499 ]
#  [10.7026437 ]
#  [10.31187929]
#  [ 9.88040259]
#  [ 9.40705952]
#  [ 8.89069602]
#  [ 8.33015801]
#  [ 7.72429142]
#  [ 7.07194218]
#  [ 6.37195621]
#  [ 5.62317945]
#  [ 4.82445782]
#  [ 3.97463724]
#  [ 3.07256365]
#  [ 2.11708297]
#  [ 1.10704114]
#  [ 0.04128407]
#  [-1.08134231]
#  [-2.26199205]]
# [['2020-04-06' '307533']
#  ['2020-04-07' '309931']
#  ['2020-04-08' '304068']
#  ['2020-04-09' '290074']
#  ['2020-04-10' '268768']
#  ['2020-04-11' '241588']
#  ['2020-04-12' '210428']
#  ['2020-04-13' '177402']
#  ['2020-04-14' '144590']
#  ['2020-04-15' '113800']
#  ['2020-04-16' '86392']
#  ['2020-04-17' '63186']
#  ['2020-04-18' '44473']
#  ['2020-04-19' '30087']
#  ['2020-04-20' '19543']
#  ['2020-04-21' '12174']
#  ['2020-04-22' '7264']
#  ['2020-04-23' '4147']
#  ['2020-04-24' '2262']
#  ['2020-04-25' '1178']
#  ['2020-04-26' '585']
#  ['2020-04-27' '276']
#  ['2020-04-28' '124']
#  ['2020-04-29' '53']
#  ['2020-04-30' '21']
#  ['2020-05-01' '8']
#  ['2020-05-02' '3']
#  ['2020-05-03' '1']
#  ['2020-05-04' '0']
#  ['2020-05-05' '0']]
